# %%
import sys
from pathlib import Path

import pandas as pd

sys.path.append(str(Path().resolve().parent))

# %%
from extract.get_raw import extract_parquet, insert_parquet_to_duck
from load.show_data import load_duckdb_data
from transform.transform_columns import rename_db_columns

db_path = Path().resolve().parents[0] / "data" / "db" / "db.db"

# %%
db_path
# Out:
# PosixPath('/home/gutto/Repos/dq-sus/src/data/db/db.db')

# %%
def main_function(disease: str = "CHIK", db_path: Path = db_path) -> pd.DataFrame:
    """
    Main function to process disease data and load it into a DataFrame.

    Args:
        disease (str): The disease to process data for. Default is "CHIK".
        db_path (Path): The path to the database. Default is db_path.

    Returns:
        pd.DataFrame: The processed data loaded into a DataFrame.
    """
    years = [2021, 2022, 2023]
    raw_data = extract_parquet(disease, years)
    insert_parquet_to_duck(raw_data)
    rename_db_columns(db_path, "sinan")
    data = load_duckdb_data("sinan")
    return data


df = main_function()
# Out:
# 2024-11-08 15:14:13,256 - INFO - Database already exists, it will be overwritten.
# 2024-11-08 15:14:13,280 - INFO - Inserting data from /home/gutto/Repos/dq-sus/src/data/parquet/CHIKBR21.parquet into the database.
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 2024-11-08 15:14:16,307 - INFO - Inserting data from /home/gutto/Repos/dq-sus/src/data/parquet/CHIKBR22.parquet into the database.
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 2024-11-08 15:14:27,258 - INFO - Inserting data from /home/gutto/Repos/dq-sus/src/data/parquet/CHIKBR23.parquet into the database.
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 2024-11-08 15:14:37,447 - INFO - All data inserted into the database successfully.
# 2024-11-08 15:14:37,448 - INFO - Column mapping for 'english' loaded successfully.
# 2024-11-08 15:14:37,535 - WARNING - The following columns were not found in the JSON mapping or database and were not renamed:
# 2024-11-08 15:14:37,536 - WARNING -  - CLINIC_CHIK
# 2024-11-08 15:14:37,536 - WARNING -  - ALMR_HEMAT
# 2024-11-08 15:14:37,546 - INFO - Loading data from table 'sinan' in DuckDB database.
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 2024-11-08 15:14:42,618 - INFO - Data loaded successfully.

# %%
df
# Out:
#        notification_type disease_condition_id notification_date  \
# 0                      2                A92.0          20210730
# 1                      2                A92.0          20210826
# 2                      2                A92.0          20210614
# 3                      2                A92.0          20210706
# 4                      2                A92.0          20210628
# ...                  ...                  ...               ...
# 651053                 2                A92.0          20230313
# 651054                 2                A92.0          20230313
# 651055                 2                A92.0          20230313
# 651056                 2                A92.0          20230313
# 651057                 2                A92.0          20230313
#
#        notification_week notification_year notification_state_id  \
# 0                 202130              2021                    26
# 1                 202134              2021                    26
# 2                 202124              2021                    26
# 3                 202127              2021                    26
# 4                 202126              2021                    26
# ...                  ...               ...                   ...
# 651053            202311              2023                    31
# 651054            202311              2023                    31
# 651055            202311              2023                    31
# 651056            202311              2023                    31
# 651057            202311              2023                    31
#
#        notification_city_id notification_region_id  \
# 0                    261160               1497
# 1                    261160               1497
# 2                    261160               1497
# 3                    260545               1497
# 4                    261160               1497
# ...                     ...                    ...
# 651053               310620               1449
# 651054               313535               1470
# 651055               316860               1465
# 651056               311700               1457
# 651057               314140               1457
#
#        notification_health_unit_id symptom_onset_date  ... platelet_count  \
# 0                          6703437           20210510  ...
# 1                          0001120           20210819  ...
# 2                          6503640           20210609  ...
# 3                          2429586           20210629  ...
# 4                          3470253           20210624  ...
# ...                            ...                ...  ...            ...
# 651053                     0022683           20230311  ...
# 651054                     2172518           20230313  ...
# 651055                     5873835           20230308  ...
# 651056                     2119935           20230310  ...
# 651057                     2120194           20230312  ...
#
#        fdh,scd_degree complications sinan_lot_number_internal_value  \
# 0
# 1
# 2
# 3
# 4
# ...               ...           ...                             ...
# 651053
# 651054
# 651055
# 651056
# 651057
#
#        sinan_system_type_intern_value sinan_duplicate_number_intern_value  \
# 0                                   2
# 1                                   2
# 2                                   2
# 3                                   2
# 4                                   2
# ...                               ...                                 ...
# 651053                              2
# 651054                              2
# 651055                              2
# 651056                              2
# 651057                              2
#
#        sinan_typing_date_intern_value sinan_record_enabled_send_intern_value  \
# 0                            20210825
# 1                            20210826
# 2                            20210706
# 3                            20210706
# 4                            20210706
# ...                               ...                                    ...
# 651053                       20230413                                      1
# 651054                       20230314                                      0
# 651055                       20230316                                      1
# 651056                       20230314                                      1
# 651057                       20230330                                      0
#
#        sinan_computer_id_intern_value sinan_windows_migration_intern_value
# 0
# 1
# 2
# 3
# 4
# ...                               ...                                  ...
# 651053
# 651054
# 651055
# 651056
# 651057
#
# [651058 rows x 122 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame
